# %%
import multiprocessing

import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pymc as pm
import pytensor.tensor as pt
from scipy.optimize import curve_fit
from scipy.stats import norm

# %%
plt.rcParams.update({
    "font.family": "serif",
    "font.size": 14,
    "axes.labelsize": 14,
    "axes.titlesize": 14,
    "legend.fontsize": 14,
    "xtick.labelsize": 14,
    "ytick.labelsize": 14,
    "figure.figsize": (5.8, 3.6),  # tipico per colonna singola
    "lines.linewidth": 1.2,
    "axes.linewidth": 0.8,
    "xtick.direction": "in",
    "ytick.direction": "in",
    "xtick.top": True,
    "ytick.right": True,
})

# %%
# ============================================================
# CONFIGURATION
# ============================================================
FILES = {
    "50d": {
        "path": "csv-files/zro2_white&green_ 50_days.csv",
        "time": 4279386,
        "calibration": {
            "a": 0.357304,
            "b": -0.295444,
            "c": 1.352297e-9,
        },
    },
    "30d": {
        "path": "csv-files/new_data.csv",
        "time": 2827661,
        "calibration": {
            "a": 0.4142675,
            "b": 2.78,
            "c": 8.4771e-7,
        },
    },
}

# %%
ENERGY_RANGE = (0, 3000)
BIN_WIDTH = 0.4

BACKGROUND_PEAKS = {
   "???" : 860.45,
    "207Tl": 897.77,
    "228Ac": 911.204,
}

FIT_WINDOW = 6

SIGNAL = {
    "mu": 871,
    "roi": (845, 920),
}

SAMPLING_CONFIG = {
    "draws": 2000,
    "tune": 2000,
    "chains": 4,
    "target_accept": 0.95,
}

# %%
# ============================================================
# ENERGY RESOLUTION
# ============================================================
def sigma_fun(E):
    """
    Detector energy resolution model.
    Returns sigma in keV.
    """
    A = 3.68436e1
    B = 1.72714e4

    return (E * np.sqrt(A / E + B / E**2)) / 2.355 / 100

# %%
# ============================================================
# DATA LOADING
# ============================================================
def load_spectrum(file_path, calibration, energy_range=(0, 3000)):
    """
    Load raw spectrum and convert channels to energy.
    """

    data = pd.read_csv(file_path, header=None)
    spectrum = data[0].to_numpy(dtype=np.float64)

    channels = np.arange(len(spectrum))

    E = (
        channels * calibration["a"]
        + calibration["b"]
        + calibration["c"] * channels**2
    )

    mask = (E >= energy_range[0]) & (E <= energy_range[1])

    return E[mask], spectrum[mask]

# %%
# ============================================================
# HISTOGRAMMING
# ============================================================
def make_histogram(E, spectrum, bins):
    counts, edges = np.histogram(E, bins=bins, weights=spectrum)
    centers = 0.5 * (edges[1:] + edges[:-1])

    return centers, counts

# %%
# ============================================================
# GAUSSIAN MODEL
# ============================================================
def gaussian_plus_bg(E, mu, sigma, area, background):
    """
    Gaussian normalized to total area + flat background.
    """

    gaussian = (
        area
        / (sigma * np.sqrt(2 * np.pi))
        * np.exp(-0.5 * ((E - mu) / sigma) ** 2)
    )

    return gaussian + background

# %%
# ============================================================
# PEAK FITTING
# ============================================================
def fit_peak(E, counts, center, window=4, plot=True):
    """
    Fit a Gaussian peak + constant background.
    """

    mask = (E > center - window) & (E < center + window)

    E_roi = E[mask]
    counts_roi = counts[mask]

    sigma_guess = sigma_fun(center)

    p0 = [
        center,
        sigma_guess,
        np.sum(counts_roi),
        np.median(counts_roi),
    ]

    bounds = (
        [center - 1, 0.01, 0, 0],
        [center + 1, 10, np.inf, np.inf],
    )

    popt, pcov = curve_fit(
        gaussian_plus_bg,
        E_roi,
        counts_roi,
        p0=p0,
        bounds=bounds,
        #sigma=np.sqrt(counts_roi),
        maxfev=10000,
    )

    perr = np.sqrt(np.diag(pcov))

    result = {
        "mu": popt[0],
        "sigma": popt[1],
        "N": popt[2],
        "B": popt[3],
        "err_mu": perr[0],
        "err_sigma": perr[1],
        "err_N": perr[2],
        "err_B": perr[3],
    }

    if plot:
        fig, ax = plt.subplots(
            2,
            1,
            figsize=(7, 6),
            sharex=True,
            gridspec_kw={"height_ratios": [3, 1]},
        )

        E_fit = np.linspace(E_roi.min(), E_roi.max(), 400)
        model_fit = gaussian_plus_bg(E_fit, *popt)

        ax[0].step(E_roi, counts_roi, where="mid", color="black", label="Data")
        ax[0].plot(E_fit, model_fit, color="red", lw=2, label="Fit")

        ax[0].set_ylabel(f"Counts / {E_roi[1]-E_roi[0]:.2f} keV")
        ax[0].set_title(f"Peak @ {center:.2f} keV")
        ax[0].legend()
        ax[0].grid(alpha=0.3)

        residuals = counts_roi - gaussian_plus_bg(E_roi, *popt)

        ax[1].scatter(E_roi, residuals, s=15)
        ax[1].axhline(0, color="red")
        ax[1].set_xlabel("Energy [keV]")
        ax[1].set_ylabel("Residuals")
        ax[1].grid(alpha=0.3)

        plt.tight_layout()
        plt.show()

    return result

# %%
# ============================================================
# BUILD TOTAL DATASET
# ============================================================
def build_total_spectrum(files_config, bins):
    all_histograms = []
    total_time = 0

    for key, cfg in files_config.items():
        E, spectrum = load_spectrum(
            cfg["path"],
            cfg["calibration"],
            ENERGY_RANGE,
        )

        E_centers, counts = make_histogram(E, spectrum, bins)

        all_histograms.append(counts)
        total_time += cfg["time"]

    total_counts = np.sum(all_histograms, axis=0)

    return E_centers, total_counts, total_time

# %%
# ============================================================
# MAIN DATA PREPARATION
# ============================================================
BINS = np.arange(
    ENERGY_RANGE[0],
    ENERGY_RANGE[1] + BIN_WIDTH,
    BIN_WIDTH
)

E_tot, Ntot, t_tot = build_total_spectrum(FILES, BINS)

print(
    f"Total counts = {np.sum(Ntot):.0f} "
    f"in {t_tot / (60 * 60 * 24):.1f} days"
)
# Out:
# Total counts = 18324 in 82.3 days

# %%
# ============================================================
# BACKGROUND PEAK FITS
# ============================================================
fit_results = {}

for peak_name, peak_energy in BACKGROUND_PEAKS.items():
    result = fit_peak(
        E_tot,
        Ntot,
        center=peak_energy,
        window=FIT_WINDOW,
        plot=True,
    )

    fit_results[peak_name] = result

    print("=" * 60)
    print(peak_name)
    print(result)
# Out:
# ============================================================
# ???
# {'mu': np.float64(860.0319648874635), 'sigma': np.float64(1.6802708894982508), 'N': np.float64(9.563505657115472), 'B': np.float64(0.703410241007188), 'err_mu': np.float64(0.38462273664159624), 'err_sigma': np.float64(0.533717131657848), 'err_N': np.float64(3.7049451852692004), 'err_B': np.float64(0.3577948656001048)}
# ============================================================
# 207Tl
# {'mu': np.float64(897.566355894476), 'sigma': np.float64(0.9578875134807306), 'N': np.float64(43.18137660896784), 'B': np.float64(1.568218620599176), 'err_mu': np.float64(0.06944878315213524), 'err_sigma': np.float64(0.07751634531016634), 'err_N': np.float64(3.5738539096880855), 'err_B': np.float64(0.4571311483459252)}
# ============================================================
# 228Ac
# {'mu': np.float64(910.4710706606719), 'sigma': np.float64(0.9456746545366558), 'N': np.float64(21.497457430484904), 'B': np.float64(1.3418785719866495), 'err_mu': np.float64(0.12079762584081194), 'err_sigma': np.float64(0.1345378886036222), 'err_N': np.float64(3.1200505358516897), 'err_B': np.float64(0.4016539457079197)}

# %% [markdown]
# -----------

# %%
s = [2.10, 0.94, 0.924 ]
E = [860, 897, 911 ]
plt.plot(E, s)

# %% [markdown]
# # PyMC

# %%
# NUOVO
roi_mask = (
    (E_tot > SIGNAL["roi"][0])
    & (E_tot < SIGNAL["roi"][1])
)

E_roi = E_tot[roi_mask]
counts_roi = Ntot[roi_mask]

# ============================================================
# SIGNAL PDF
# ============================================================
mu_signal = SIGNAL["mu"]
sigma_signal = sigma_fun(mu_signal)

PDF_signal = norm.pdf(E_roi, mu_signal, sigma_signal)


# ============================================================
# BACKGROUND INFO
# ============================================================
background_names = list(BACKGROUND_PEAKS.keys())
background_energies = np.array(list(BACKGROUND_PEAKS.values()))

# valori iniziali per i sigma
background_sigmas = sigma_fun(background_energies)

# %%
# ============================================================
# BAYESIAN MODEL
# ============================================================
with pm.Model() as model:

    # --------------------------------------------------------
    # BACKGROUND PARAMETERS
    # --------------------------------------------------------
    A_bg = []
    mu_bg = []
    sigma_bg = []
    PDF_bg_list = []

    for peak_name in background_names:

        fit = fit_results[peak_name]

        # ------------------------
        # Amplitude prior
        # ------------------------
        A = pm.TruncatedNormal(
            f"A_{peak_name}",
            mu=fit["N"],
            sigma=max(fit["err_N"], 5.0),
            lower=0,
        )

        # ------------------------
        # Mean prior
        # ------------------------
        mu = pm.Normal(
            f"mu_{peak_name}",
            mu=fit["mu"],
            sigma=max(fit["err_mu"], 1),
        )

        # ------------------------
        # Sigma prior
        # ------------------------
        sigma0 = sigma_fun(fit["mu"])

        sigma = pm.TruncatedNormal(
            f"sigma_{peak_name}",
            mu=sigma0,
            sigma=max(0.2 * sigma0, 1),
            lower=1e-3,
        )

        # ------------------------
        # Dynamic PDF
        # ------------------------
        pdf = (
            1.0 / (sigma * np.sqrt(2 * np.pi))
        ) * pt.exp(
            -0.5 * ((E_roi - mu) / sigma) ** 2
        )

        A_bg.append(A)
        mu_bg.append(mu)
        sigma_bg.append(sigma)
        PDF_bg_list.append(pdf)

    A_bg = pt.stack(A_bg)
    mu_bg = pt.stack(mu_bg)
    sigma_bg = pt.stack(sigma_bg)

    PDF_bg = pt.stack(PDF_bg_list)

    # --------------------------------------------------------
    # SIGNAL PRIOR
    # --------------------------------------------------------
    A_signal = pm.HalfNormal(
        "A_signal",
        sigma=500,
    )

    # --------------------------------------------------------
    # FLAT BACKGROUND PRIOR
    # --------------------------------------------------------
    Q = pm.HalfNormal(
        "Q",
        sigma=500,
    )

    # --------------------------------------------------------
    # EXPECTED COUNTS
    # --------------------------------------------------------
    lambda_E = (
        Q
        + pt.sum(A_bg[:, None] * PDF_bg, axis=0)
        + A_signal * PDF_signal
    )

    # numerical stability
    lambda_E = pt.clip(lambda_E, 1e-9, np.inf)

    # --------------------------------------------------------
    # LIKELIHOOD
    # --------------------------------------------------------
    pm.Poisson(
        "counts_obs",
        mu=lambda_E,
        observed=counts_roi,
    )

    # --------------------------------------------------------
    # SAMPLING
    # --------------------------------------------------------
    trace = pm.sample(
        draws=SAMPLING_CONFIG["draws"],
        tune=SAMPLING_CONFIG["tune"],
        chains=SAMPLING_CONFIG["chains"],
        cores=min(4, multiprocessing.cpu_count()),
        target_accept=SAMPLING_CONFIG["target_accept"],
        init="jitter+adapt_diag",
        return_inferencedata=True,
        progressbar=True,
    )
# Out:
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [A_???, mu_???, sigma_???, A_207Tl, mu_207Tl, sigma_207Tl, A_228Ac, mu_228Ac, sigma_228Ac, A_signal, Q]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 2_000 tune and 2_000 draw iterations (8_000 + 8_000 draws total) took 4 seconds.

# %%
# ============================================================
# CORRELATION PLOTS
# ============================================================
axes = az.plot_pair(
    trace,
    kind="kde",
    marginals=True,
    figsize=(8, 8),
    textsize=9,
)

for ax in axes.flatten():
    ax.grid(alpha=0.35)

plt.tight_layout()
plt.show()
# Out:
# /home/ritaferi/pymc-env/lib/python3.12/site-packages/arviz/plots/backends/matplotlib/pairplot.py:223: UserWarning: rcParams['plot.max_subplots'] (40) is smaller than the number of resulting pair plots with these variables, generating only a 8x8 grid
#   warnings.warn(

# %%
# ============================================================
# POSTERIOR OF SIGNAL
# ============================================================
signal_samples = trace.posterior["A_signal"].values.flatten()

N_signal_90 = np.percentile(signal_samples, 90)
N_signal_95 = np.percentile(signal_samples, 95)

print()
print("=" * 60)
print(f"90% upper limit on signal counts : {N_signal_90:.3f}")
print(f"95% upper limit on signal counts : {N_signal_95:.3f}")
print("=" * 60)
# Out:
# ============================================================
# 90% upper limit on signal counts : 3.563
# 95% upper limit on signal counts : 4.218
# ============================================================

# %%
# ============================================================
# SIGNAL POSTERIOR PLOT
# ============================================================
plt.figure(figsize=(7, 5))

plt.hist(signal_samples, bins=80, density=True)

plt.axvline(
    N_signal_90,
    linestyle="--",
    label=f"90% CL = {N_signal_90:.2f}",
)

plt.axvline(
    N_signal_95,
    linestyle=":",
    label=f"95% CL = {N_signal_95:.2f}",
)

plt.xlabel("Signal counts")
plt.ylabel("Posterior density")
plt.grid(alpha=0.3)
plt.xlim(0,10)
plt.legend()

plt.tight_layout()
plt.show()

# %%
posterior_means = {name: trace.posterior[name].mean().values for name in trace.posterior.data_vars}

print("Ampiezze medie dei picchi:")
for name, val in posterior_means.items():
    print(f"{name}: {val:.2f}")
# Out:
# Ampiezze medie dei picchi:
# mu_???: 860.04
# mu_207Tl: 897.52
# mu_228Ac: 910.48
# A_???: 6.32
# sigma_???: 1.41
# A_207Tl: 44.53
# sigma_207Tl: 1.05
# A_228Ac: 22.18
# sigma_228Ac: 1.04
# A_signal: 1.76
# Q: 1.26

# %%
sigma_fun(860)
# Out:
# np.float64(0.939541625388756)

# %%
background_names = list(BACKGROUND_PEAKS.keys())
background_energies = np.array(list(BACKGROUND_PEAKS.values()))
background_sigmas = sigma_fun(background_energies)

# %%
# ============================================================
# SUMMARY
# ============================================================
summary = az.summary(trace, round_to=4)
print(summary)


# ============================================================
# POSTERIOR EXTRACTION
# ============================================================
idata = trace
posterior = idata.posterior

Q_s = posterior["Q"].values.flatten()
A_signal_s = posterior["A_signal"].values.flatten()

A_bg_s = {
    name: posterior[f"A_{name}"].values.flatten()
    for name in background_names
}

mu_bg_s = {
    name: posterior[f"mu_{name}"].values.flatten()
    for name in background_names
}

sigma_bg_s = {
    name: posterior[f"sigma_{name}"].values.flatten()
    for name in background_names
}


# ============================================================
# COSTRUZIONE λ(E) POSTERIORE
# ============================================================
lambda_samples = []
lambda_back = []

n_samples = len(Q_s)

for i in range(n_samples):

    # fondo piatto
    lam = Q_s[i] * np.ones_like(E_roi)
    lam_bkg = Q_s[i] * np.ones_like(E_roi)

    # background peaks
    for name in background_names:

        mu_i = mu_bg_s[name][i]
        sigma_i = sigma_bg_s[name][i]
        A_i = A_bg_s[name][i]

        pdf_i = norm.pdf(E_roi, mu_i, sigma_i)

        lam += A_i * pdf_i
        lam_bkg += A_i * pdf_i

    # signal
    lam += A_signal_s[i] * PDF_signal

    lambda_samples.append(lam)
    lambda_back.append(lam_bkg)

lambda_samples = np.array(lambda_samples)
lambda_back = np.array(lambda_back)


# ============================================================
# POSTERIOR STATISTICS
# ============================================================
lambda_mean = np.mean(lambda_samples, axis=0)

lambda_low = np.percentile(
    lambda_back,
    5,
    axis=0,
)

lambda_high = np.percentile(
    lambda_back,
    95,
    axis=0,
)


# ============================================================
# BACKGROUND RECONSTRUCTION
# ============================================================
posterior_means = {
    var: posterior[var].values.mean()
    for var in posterior.data_vars
}

lambda_pred_bkg = (
    posterior_means["Q"]
    * np.ones_like(E_roi)
)

for name in background_names:

    mu_mean = posterior_means[f"mu_{name}"]
    sigma_mean = posterior_means[f"sigma_{name}"]
    A_mean = posterior_means[f"A_{name}"]

    pdf_mean = norm.pdf(
        E_roi,
        mu_mean,
        sigma_mean,
    )

    lambda_pred_bkg += A_mean * pdf_mean


# ============================================================
# 90% SIGNAL UPPER LIMIT
# ============================================================
N_signal_90 = np.percentile(
    A_signal_s,
    90,
)

lambda_pred = (
    lambda_pred_bkg
    + N_signal_90 * PDF_signal
)
# Out:
#                  mean      sd    hdi_3%   hdi_97%  mcse_mean  mcse_sd  \
# mu_???       860.0401  0.5665  859.0140  861.1452     0.0058   0.0070
# mu_207Tl     897.5243  0.1179  897.2972  897.7394     0.0013   0.0015
# mu_228Ac     910.4753  0.1740  910.1590  910.8112     0.0020   0.0021
# A_???          6.3221  2.2816    2.1286   10.6684     0.0283   0.0269
# sigma_???      1.4103  0.4402    0.6425    2.2991     0.0047   0.0062
# A_207Tl       44.5268  3.4074   37.9988   50.7639     0.0353   0.0388
# sigma_207Tl    1.0496  0.1137    0.8515    1.2689     0.0012   0.0013
# A_228Ac       22.1829  2.8178   16.8411   27.4454     0.0309   0.0309
# sigma_228Ac    1.0355  0.1602    0.7559    1.3423     0.0019   0.0020
# A_signal       1.7614  1.2768    0.0010    4.0698     0.0141   0.0152
# Q              1.2611  0.0961    1.0752    1.4361     0.0011   0.0011
#
#               ess_bulk   ess_tail   r_hat
# mu_???       9640.3260  5931.9345  1.0009
# mu_207Tl     7792.8336  4910.4230  1.0001
# mu_228Ac     7282.0783  4552.6542  1.0000
# A_???        5977.2992  3530.5685  1.0001
# sigma_???    8181.2848  4277.7754  1.0003
# A_207Tl      9263.7600  5218.3709  1.0011
# sigma_207Tl  8894.2294  6377.0336  1.0013
# A_228Ac      8226.1296  5646.9546  1.0008
# sigma_228Ac  6943.9580  5648.0454  1.0000
# A_signal     5206.1829  3060.2358  1.0007
# Q            7011.7336  5673.5017  1.0002

# %%
# ============================================================
# RESIDUALS
# ============================================================
residuals = (counts_roi - lambda_mean) / np.sqrt(counts_roi + 1)


# ============================================================
# OPTIONAL: PRINT RESULTS
# ============================================================
print("\n==============================")
print("RESULTS")
print("==============================")

print(f"Signal 90% UL = {N_signal_90:.3f}")

for name in background_names:
    print(
        f"{name}: "
        f"A = {posterior_means[f'A_{name}']:.3f}, "
        f"mu = {posterior_means[f'mu_{name}']:.3f}, "
        #f"sigma = {posterior_means[f'sigma_{name}']:.3f}"
    )
# Out:
# ==============================
# RESULTS
# ==============================
# Signal 90% UL = 3.563
# ???: A = 6.322, mu = 860.040,
# 207Tl: A = 44.527, mu = 897.524,
# 228Ac: A = 22.183, mu = 910.475,

# %%
# ============================================================
# SUMMARY
# ============================================================
summary = az.summary(trace, round_to=4)
print(summary)

# ============================================================
# POSTERIOR EXTRACTION
# ============================================================
idata = trace
posterior = idata.posterior

Q_s = posterior["Q"].values.flatten()
A_signal_s = posterior["A_signal"].values.flatten()

A_bg_s = {
    name: posterior[f"A_{name}"].values.flatten()
    for name in background_names
}

mu_bg_s = {
    name: posterior[f"mu_{name}"].values.flatten()
    for name in background_names
}

sigma_bg_s = {
    name: posterior[f"sigma_{name}"].values.flatten()
    for name in background_names
}

# ============================================================
# GRID FINE
# ============================================================
E_fine = np.linspace(
    E_roi.min(),
    E_roi.max(),
    4000
)

# ============================================================
# PDF SEGNALE SU GRID FINE
# ============================================================
from scipy.interpolate import interp1d
from scipy.stats import norm

interp_signal = interp1d(
    E_roi,
    PDF_signal,
    kind='cubic',
    bounds_error=False,
    fill_value=0
)

PDF_signal_fine = interp_signal(E_fine)

# ============================================================
# COSTRUZIONE λ(E) POSTERIORE
# ============================================================
lambda_samples = []
lambda_back = []

n_samples = len(Q_s)

for i in range(n_samples):

    # --------------------------------------------------------
    # fondo piatto
    # --------------------------------------------------------
    lam = Q_s[i] * np.ones_like(E_roi)
    lam_bkg = Q_s[i] * np.ones_like(E_roi)

    # --------------------------------------------------------
    # background peaks
    # --------------------------------------------------------
    for name in background_names:

        mu_i = mu_bg_s[name][i]
        sigma_i = sigma_bg_s[name][i]
        A_i = A_bg_s[name][i]

        pdf_i = norm.pdf(
            E_roi,
            mu_i,
            sigma_i
        )

        lam += A_i * pdf_i
        lam_bkg += A_i * pdf_i

    # --------------------------------------------------------
    # signal
    # --------------------------------------------------------
    lam += A_signal_s[i] * PDF_signal

    lambda_samples.append(lam)
    lambda_back.append(lam_bkg)

lambda_samples = np.array(lambda_samples)
lambda_back = np.array(lambda_back)

# ============================================================
# POSTERIOR STATISTICS
# ============================================================
lambda_mean = np.mean(
    lambda_samples,
    axis=0
)

lambda_low = np.percentile(
    lambda_back,
    5,
    axis=0
)

lambda_high = np.percentile(
    lambda_back,
    95,
    axis=0
)

# ============================================================
# INCERTEZZA MODELLO
# ============================================================
model_std = np.std(
    lambda_samples,
    axis=0
)

# ============================================================
# BACKGROUND RECONSTRUCTION
# ============================================================
posterior_means = {
    var: posterior[var].values.mean()
    for var in posterior.data_vars
}

# ============================================================
# MODELLO LISCIO
# ============================================================
lambda_pred_bkg_fine = (
    posterior_means["Q"]
    * np.ones_like(E_fine)
)

for name in background_names:

    mu_mean = posterior_means[f"mu_{name}"]
    sigma_mean = posterior_means[f"sigma_{name}"]
    A_mean = posterior_means[f"A_{name}"]

    pdf_mean_fine = norm.pdf(
        E_fine,
        mu_mean,
        sigma_mean
    )

    lambda_pred_bkg_fine += (
        A_mean * pdf_mean_fine
    )

# ============================================================
# 90% SIGNAL UPPER LIMIT
# ============================================================
N_signal_90 = np.percentile(
    A_signal_s,
    90
)

lambda_pred_fine = (
    lambda_pred_bkg_fine
    + N_signal_90 * PDF_signal_fine
)

# ============================================================
# RESIDUI NORMALIZZATI
# ============================================================
total_sigma = np.sqrt(
    lambda_mean + model_std**2
)

residuals = (
    counts_roi - lambda_mean
) / total_sigma

# ============================================================
# FIGURA
# ============================================================
fig, (ax1, ax2) = plt.subplots(
    2,
    1,
    sharex=True,
    gridspec_kw={"height_ratios": [3, 1]},
    figsize=(8, 6)
)

# ============================================================
# PLOT SUPERIORE
# ============================================================
ax1.step(
    E_roi,
    counts_roi,
    where='mid',
    color='grey',
    alpha=0.6,
    label='Data'
)

# ------------------------------------------------------------
# modello totale
# ------------------------------------------------------------
ax1.plot(
    E_fine,
    lambda_pred_fine,
    color='green',
    lw=2,
    label='90% C.L. limit'
)

# ------------------------------------------------------------
# background fit
# ------------------------------------------------------------
ax1.plot(
    E_fine,
    lambda_pred_bkg_fine,
    color='red',
    lw=2,
    label='Background fit'
)

# ------------------------------------------------------------
# banda credibile
# ------------------------------------------------------------
ax1.fill_between(
    E_roi,
    lambda_low,
    lambda_high,
    color='red',
    alpha=0.2
)

ax1.set_yscale('log')

ax1.set_ylabel(
    f"Counts / {E_roi[1]-E_roi[0]:.2f} keV"
)

ax1.grid(alpha=0.15)

# ============================================================
# ANNOTAZIONI
# ============================================================
ax1.annotate(
    "871.1 keV",
    xy=(871.1 - 3, 5),
    rotation=90,
    fontsize=11
)

ax1.vlines(
    871,
    0,
    30,
    ls='--',
    color='black',
    alpha=0.75
)

# ------------------------------------------------------------
# 207Tl
# ------------------------------------------------------------
ax1.annotate(
    r"$^{207}$Tl",
    xy=(897 - 3, 15),
    rotation=90,
    fontsize=11
)

ax1.vlines(
    posterior_means['mu_207Tl'],
    0,
    30,
    ls='--',
    color='black',
    alpha=0.75
)

# ------------------------------------------------------------
# 228Ac
# ------------------------------------------------------------
ax1.annotate(
    r"$^{228}$Ac",
    xy=(911 - 3, 12),
    rotation=90,
    fontsize=11
)

ax1.vlines(
    posterior_means['mu_228Ac'],
    0,
    30,
    ls='--',
    color='black',
    alpha=0.75
)

# ------------------------------------------------------------
# peak ignoto
# ------------------------------------------------------------
ax1.annotate(
    r"$^{208}$Tl + $^{208}$Pb$(n,n'\gamma)$",
    xy=(860 - 3, 5),
    rotation=90,
    fontsize=11
)
# sostituisci ??? con nome corretto
# esempio:
# posterior_means['mu_208Tl']

ax1.vlines(    posterior_means['mu_???'],
     0,
     30,
     ls='--',
     color='black',
     alpha=0.75
 )

# ============================================================
# LEGEND
# ============================================================
ax1.legend(
    loc="lower center",
    bbox_to_anchor=(0.5, 0.98),
    ncol=3,
    fontsize=12
)

# ============================================================
# PLOT RESIDUI
# ============================================================
ax2.scatter(
    E_roi,
    residuals,
    s=6,
    color='black',
    zorder=10
)

ax2.axhspan(
    -3,
    3,
    color='red',
    alpha=0.25
)

ax2.axhspan(
    -2,
    2,
    color='orange',
    alpha=0.2
)

ax2.axhspan(
    -1,
    1,
    color='green',
    alpha=0.15
)

ax2.axhline(
    0,
    color='gray'
)

ax2.set_xlabel("Energy [keV]")
ax2.set_ylabel("Pulls")

ax2.grid(alpha=0.2)

# ============================================================
# LIMITI ASSI
# ============================================================
ax1.set_xlim(845, 920)
ax2.set_ylim(-4, 4)

# ============================================================
# LAYOUT
# ============================================================
plt.subplots_adjust(hspace=0)

plt.show()
# Out:
#                  mean      sd    hdi_3%   hdi_97%  mcse_mean  mcse_sd  \
# mu_???       860.0401  0.5665  859.0140  861.1452     0.0058   0.0070
# mu_207Tl     897.5243  0.1179  897.2972  897.7394     0.0013   0.0015
# mu_228Ac     910.4753  0.1740  910.1590  910.8112     0.0020   0.0021
# A_???          6.3221  2.2816    2.1286   10.6684     0.0283   0.0269
# sigma_???      1.4103  0.4402    0.6425    2.2991     0.0047   0.0062
# A_207Tl       44.5268  3.4074   37.9988   50.7639     0.0353   0.0388
# sigma_207Tl    1.0496  0.1137    0.8515    1.2689     0.0012   0.0013
# A_228Ac       22.1829  2.8178   16.8411   27.4454     0.0309   0.0309
# sigma_228Ac    1.0355  0.1602    0.7559    1.3423     0.0019   0.0020
# A_signal       1.7614  1.2768    0.0010    4.0698     0.0141   0.0152
# Q              1.2611  0.0961    1.0752    1.4361     0.0011   0.0011
#
#               ess_bulk   ess_tail   r_hat
# mu_???       9640.3260  5931.9345  1.0009
# mu_207Tl     7792.8336  4910.4230  1.0001
# mu_228Ac     7282.0783  4552.6542  1.0000
# A_???        5977.2992  3530.5685  1.0001
# sigma_???    8181.2848  4277.7754  1.0003
# A_207Tl      9263.7600  5218.3709  1.0011
# sigma_207Tl  8894.2294  6377.0336  1.0013
# A_228Ac      8226.1296  5646.9546  1.0008
# sigma_228Ac  6943.9580  5648.0454  1.0000
# A_signal     5206.1829  3060.2358  1.0007
# Q            7011.7336  5673.5017  1.0002

# %% [markdown]
# # Half life

# %%
# Dati campione
m_sample = 551.3        # massa ZrO2 in grammi
Mr_sample = 123.22      # massa molare ZrO2 [g/mol]
N_A = 6.022e23          # numero di Avogadro
eff_94Zr = 0.0294935    # efficienza di rivelazione
i_a_94Zr = 0.1738       # abbondanza isotopica
t_live =    t_tot/(60*60*24*365)             # 90 giorni in anni

# Posterior del numero di eventi segnale
signal_samples = trace.posterior['A_signal'].values.flatten()

# Numero di nuclei 96Zr nel campione
N_nuclei = (m_sample * i_a_94Zr / Mr_sample) * N_A

percentile = 90

T_half_limit = (np.log(2) * N_nuclei * eff_94Zr * t_live) / np.percentile(signal_samples, percentile)
print(f"T1/2 > {T_half_limit:.2e} yrs at {percentile}%")
# Out:
# T1/2 > 6.05e+20 yrs at 90%

# %%
m_sample * i_a_94Zr * t_tot # gr * s
m_sample * i_a_94Zr * 0.001 * ( t_tot/(60*60) )
# Out:
# 189.1578858136611

# %%
np.percentile(signal_samples, percentile)
# Out:
# np.float64(3.5632188312107074)
